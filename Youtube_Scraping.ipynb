# %%
import os
import numpy as np
import pandas as pd
import googleapiclient.discovery

# %%
os.getcwd()
# Out:
# '/content'

# %%
api_service_name = 'youtube'
api_version = 'v3'
DEVELOPER_KEY = 'api_key'
video_id = '0FtcHjI5lmw'

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY
)

# %%
def get_comments(video, amount):
  request = youtube.commentThreads().list(
      part='snippet',
      videoId=video,
      maxResults=amount
      )

  response = request.execute()

  comments = []
  count = 0

  while(count < amount):
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])
      count += 1

  return comments

# %%
comments_data_frame = pd.DataFrame(get_comments(video_id, 1000), columns=['author', 'publish_date', 'amount_of_likes', 'comment', 'video_id', 'public'])

# %%
comments_data_frame
# Out:
#                      author          publish_date  amount_of_likes  \
# 0        @analyticswithadam  2024-02-06T20:59:40Z                0
# 1         @BECEOOYaashuDave  2024-01-31T18:15:09Z                0
# 2           @yuxrazafar8532  2024-01-28T13:38:45Z                0
# 3          @user-qo3ko1ex2f  2024-01-23T22:34:59Z                0
# 4     @sarvarbekfozilov9829  2024-01-15T08:52:52Z                0
# ...                     ...                   ...              ...
# 998             @damochi100  2023-11-22T19:10:38Z                1
# 999          @rahulbora7323  2023-11-21T17:00:34Z                0
# 1000        @gsonbiswas9765  2023-11-20T13:25:15Z                0
# 1001    @emmanuel.alcantara  2023-11-13T03:06:36Z                0
# 1002           @duchess4738  2023-11-11T15:37:56Z                1
#
#                                                 comment     video_id  public
# 0     Updated Video with Replies https://youtu.be/A1...  0FtcHjI5lmw    True
# 1     What if i want to extract the replies as well?...  0FtcHjI5lmw    True
# 2     I want to extract the comments from a playlist...  0FtcHjI5lmw    True
# 3     Very useful video. Thank you for sharing shari...  0FtcHjI5lmw    True
# 4     #question\nhi adam thank for tutorial.\ncurren...  0FtcHjI5lmw    True
# ...                                                 ...          ...     ...
# 998                           does exactly what it says  0FtcHjI5lmw    True
# 999   Very informative video!!!\nCan you help me wit...  0FtcHjI5lmw    True
# 1000               Does it extract the nested comments?  0FtcHjI5lmw    True
# 1001  how can I extract for example the 967 comments...  0FtcHjI5lmw    True
# 1002  Great video! Do you know how much of your quot...  0FtcHjI5lmw    True
#
# [1003 rows x 6 columns]

# %%
len(comments_data_frame)
# Out:
# 1003
